# %% [markdown]
# <a href="https://colab.research.google.com/github/BettKelvin-spec/CBR/blob/main/first_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **My First ML Project**

# %% [markdown]
# ## **Load data**

# %%
import pandas as pd
df = pd.read_csv('CBR (2).csv')
df
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 0                2.72                         9.3                  54.3
# 1                2.76                         9.6                  55.0
# 2                2.69                         9.1                  53.6
# 3                2.72                         9.5                  54.2
# 4                2.66                         9.0                  53.1
# ..                ...                         ...                   ...
# 175              2.71                        10.6                  56.0
# 176              2.63                        10.3                  54.3
# 177              2.66                        10.4                  54.9
# 178              2.68                        10.4                  55.3
# 179              2.69                        10.6                  55.6
#
#      Plastic limit, WP (%)  Plasticity index, PI (%)  \
# ...

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data separation as x and y**

# %%
y = df['Soaked California bearing ratio, CBRs (%)']
y
# Out:
# 0      17
# 1      17
# 2      18
# 3      17
# 4      18
#        ..
# 175    14
# 176    15
# 177    15
# 178    14
# 179    14
# Name: Soaked California bearing ratio, CBRs (%), Length: 180, dtype: int64

# %%
x = df.drop('Soaked California bearing ratio, CBRs (%)', axis=1)
x
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 0                2.72                         9.3                  54.3
# 1                2.76                         9.6                  55.0
# 2                2.69                         9.1                  53.6
# 3                2.72                         9.5                  54.2
# 4                2.66                         9.0                  53.1
# ..                ...                         ...                   ...
# 175              2.71                        10.6                  56.0
# 176              2.63                        10.3                  54.3
# 177              2.66                        10.4                  54.9
# 178              2.68                        10.4                  55.3
# 179              2.69                        10.6                  55.6
#
#      Plastic limit, WP (%)  Plasticity index, PI (%)  \
# ...

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)
x_train
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 164              2.59                         9.7                  54.1
# 120              2.68                         9.3                  46.3
# 95               2.70                         9.2                  48.1
# 165              2.64                         9.9                  55.2
# 29               2.71                         9.2                  50.7
# ..                ...                         ...                   ...
# 87               2.62                         8.3                  41.1
# 103              2.66                        10.2                  51.2
# 67               2.59                         8.3                  41.2
# 24               2.67                         9.0                  50.1
# 8                2.68                         9.0                  53.5
#
#      Plastic limit, WP (%)  Plasticity index, PI (%)  \
# ...

# %%
x_test
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 88               2.64                         8.3                  41.5
# 145              2.67                         8.5                  42.9
# 11               2.72                         8.8                  48.6
# 74               2.60                         7.6                  37.6
# 173              2.71                        10.9                  56.1
# 150              2.67                        10.0                  52.3
# 151              2.70                        10.3                  53.0
# 97               2.65                         9.0                  47.2
# 90               2.71                         9.3                  48.3
# 96               2.62                         8.8                  46.6
# 147              2.62                         8.3                  42.0
# 65               2.64                         8.5                  42.1
# ...

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Linear regression**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
print(y_lr_train_pred,)
# Out:
# [15.21438716 16.74419676 19.86316049 14.23858737 20.06665457 17.62670152
#  14.10065809 14.63277127 23.02833465 17.22267284 14.16866769 16.3577139
#  19.61072244 24.4832158  20.22475488 15.03521094 29.95758085 19.18174394
#  17.64652634 19.62021513 22.60351981 23.39536629 16.88583762 19.95510673
#  23.8356857  15.79008173 22.33994496 18.22636383 20.61867675 15.71310381
#  17.7809999  18.2077227  25.30781525 20.92726813 22.42160451 18.78707049
#  19.65700369 19.67646012 19.0850091  17.8863704  17.8846829  19.7629067
#  25.03649008 14.13401298 16.83071139 20.88838629 17.73145367 16.515112
#  22.54403046 18.81101832 17.43135304 14.19977852 17.13197294 14.59526073
#  24.9326119  21.26401348 18.12280118 29.64864325 13.97132575 17.29278219
#  19.9575348  24.38181915 17.42802737 26.11845976 29.3242823  19.1487048
#  29.71623259 20.86510919 14.23301752 13.63447721 22.06569014 14.47825492
#  21.38592443 15.25734036 23.67297173 17.4824583  17.35971433 24.96299005
# ...

# %%
y_lr_test_pred
# Out:
# array([21.08170132, 19.78786263, 24.46920273, 24.53568039, 13.65010191,
#        16.62438606, 16.07014843, 22.51348998, 25.86785263, 21.15675784,
#        20.58197277, 20.51944792, 20.2835559 , 15.1793833 , 20.19105674,
#        22.26519669, 21.05103283, 18.35017381, 24.53927105, 28.87213098,
#        16.85580502, 23.13556308, 16.39039704, 23.17975715, 30.32263612,
#        16.79616296, 23.83194084, 16.02139714, 21.2866956 , 13.527887  ,
#        20.29473029, 20.92001429, 20.98009356, 17.06129662, 16.86601279,
#        14.13136949])

# %% [markdown]
# ## **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)

lr_train_r2 = r2_score(y_train, y_lr_train_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE  Test R2
# 0  Linear regression     0.079077    0.993849  0.079901  0.99487

# %% [markdown]
# # **Random Forest**

# %% [markdown]
# ## Training the model

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ## Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)

rf_train_r2 = r2_score(y_train, y_rf_train_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random Forest     0.438768    0.965869  0.586032  0.962377

# %% [markdown]
# ## Model comparison

# %%
df_models = pd.concat([lr_results, rf_results], axis=0).reset_index()
df_models.drop(['index'], axis=1, inplace=True)
df_models
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.007536    0.764505  1.020695  0.789162
# 1      Random Forest     0.438768    0.965869  0.586032  0.962377

# %% [markdown]
# # **Data visualization**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x = y_train, y = y_lr_train_pred, c = "#7CAE00", alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predicted CBR')
plt.xlabel('Actual CBR')
# Out:
# Text(0.5, 0, 'Actual CBR')
